# %% [markdown]
# H0: On social media, ave number of friends (x bar) = 130.8 with sd = 53
# Number of samples n = 40
# Margin of error = Z-cretical x standard error = 1.96 * (53 / sq root of 40) = 16.4
# Point estimare (x-bar) = 130.8
# intervel wstimare = x bar +/ margin of error = (130.8 - 16.4) to (130.8 + 16.4) = 114.4 to 147.2

# %% [markdown]
# SAMPLES
#
# Sample Number   x-bar   s   n   Intervel estimare   In range?
#                                 Confidence Intervevl
# 1               125     12  50  121 to 128          YES
# 2               135     23  50  124 to 139          YES
# ...
# 100             100     9   50  97 to 102           NO

# %% [markdown]
# Alpha = level of significance = Rejection Zone = Prob(Type 1 error)
# Beta = Level of confidence = 1-alpha = 0.95
#
# Therefore, CONFIDENCE LEVEL: Beta = 0.95 = 95%
# => We are confident that at least 95 of the above 100 samples will have a Confidence Intervel(CI)  that falls in the IE(Interel Estimate)
# => We are confident that the above table will show YES in the "In Range" column for at least 95 cases
