# %%
import pandas as pd

# %%
name = ['riya', 'rajiv', 'richa','ram']
series_n = pd.Serise(name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 name = ['riya', 'rajiv', 'richa','ram']
# ----> 2 series_n = pd.Serise(name)
#
# AttributeError: module 'pandas' has no attribute 'Serise'
