# %%
'''Consider the file train_v9rqX0R.csv from the hackathon https://www.analyticsvidhya.com/datahack/contest/practice-problem-big-mart-sales-iii/ 
This problem is of Regression with label as “Item_Outlet_Sales”. Note that the variables Item_Identifier and Outlet_Identifier are together a composite key, hence not to be taken as features. 
Do the following:
    Clean the data from missing and any discrepancies
    Do the train test split 
    Build at least 3 models and evaluate their performance'''

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
# from sklea

# %%
df = pd.read_csv('dataset_assignment1/train_v9rqX0R.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# checking for null values

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# handling null values with mean imputer

# %%
mean_imputer = SimpleImputer(strategy='mean')
mode_imputer = SimpleImputer(strategy='most_frequent')

# %%
# df['Item_Weight'] = df['Item_Weight'].isna().replace(df['Item_Weight'].mean())
df['Item_Weight'] = mean_imputer.fit(df[['Item_Weight']])
df['Outlet_Size'] = mode_imputer.fit(df[['Outlet_Size']])
# df['Outlet_Size'] = df['Outlet_Size'].isna().replace(df['Outlet_Size'].median())

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# applying encoding to data

# %%
ohe = OneHotEncoder(sparse_output=False, )
